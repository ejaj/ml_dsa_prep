# %% [markdown]
# ### Case Study 1: Fraud Detection in Financial Transactions
# **Goal: Build a pipeline to detect suspicious transactions using tabular features.**

# %%
import pandas as pd
import numpy as np
np.random.seed(42)

# %%
df = pd.read_csv('transactions.csv')
df
# Out:
#   transaction_id user_id   amount location              time      device  \
# 0          T1001    U001   850.00       LA  2024-05-10 12:34  Galaxy S21
# 1          T1002    U002      NaN       NY  2024-05-11 09:20   iPhone 14
# 2          T1003    U003     0.00       TX  2024-06-01 23:59     Pixel 6
# 3          T1004    U004  1299.50       SF  2024-06-13 03:45   iPhone 13
# 4          T1005    U005   450.75       NY  2024-06-14 18:20   OnePlus 9
#
#    is_fraud
# 0         0
# 1         1
# 2         0
# 3         1
# 4         0

# %%
df.isnull().sum()
# Out:
# transaction_id    0
# user_id           0
# amount            1
# location          0
# time              0
# device            0
# is_fraud          0
# dtype: int64

# %%
df.shape[0]
# Out:
# 5

# %%
# Data cleaning
# Remove rows where amount is missing or ≤ 0
df_clean = df[df['amount'].notna() & (df['amount']>0)].copy()
df_clean
# Out:
#   transaction_id user_id   amount location              time      device  \
# 0          T1001    U001   850.00       LA  2024-05-10 12:34  Galaxy S21
# 3          T1004    U004  1299.50       SF  2024-06-13 03:45   iPhone 13
# 4          T1005    U005   450.75       NY  2024-06-14 18:20   OnePlus 9
#
#    is_fraud
# 0         0
# 3         1
# 4         0

# %%
# Feature Engineering
# Create hour, is_night, adn amount_zscore
df_clean['hour'] = pd.to_datetime(df_clean['time']).dt.hour
df_clean['is_night'] = df_clean['hour'].apply(lambda h:1 if h < 6 or h<22 else 0)
df_clean['amount_zscore'] = (df_clean['amount'] - df_clean['amount'].mean()) / df_clean['amount'].std()
df_clean
# Out:
#   transaction_id user_id   amount location              time      device  \
# 0          T1001    U001   850.00       LA  2024-05-10 12:34  Galaxy S21
# 3          T1004    U004  1299.50       SF  2024-06-13 03:45   iPhone 13
# 4          T1005    U005   450.75       NY  2024-06-14 18:20   OnePlus 9
#
#    is_fraud  hour  is_night  amount_zscore
# 0         0    12         1      -0.039447
# 3         1     3         1       1.019140
# 4         0    18         1      -0.979693

# %%
# Group-Based Aggregates
# For each user, compute avg amount, max amount

# user_stats = df_clean.groupby('user_id')['amount'].agg(
#     mean_user='mean',
#     max_user='max'
# ).reset_index()
# df_grop = df_clean.merge(user_stats, on='user_id')

user_stats = df_clean.groupby('user_id')['amount'].agg(['mean','max']).reset_index()
df_grop = df_clean.merge(user_stats, on='user_id', suffixes=('', '_user'))
df_grop
# Out:
#   transaction_id user_id   amount location              time      device  \
# 0          T1001    U001   850.00       LA  2024-05-10 12:34  Galaxy S21
# 1          T1004    U004  1299.50       SF  2024-06-13 03:45   iPhone 13
# 2          T1005    U005   450.75       NY  2024-06-14 18:20   OnePlus 9
#
#    is_fraud  hour  is_night  amount_zscore     mean      max
# 0         0    12         1      -0.039447   850.00   850.00
# 1         1     3         1       1.019140  1299.50  1299.50
# 2         0    18         1      -0.979693   450.75   450.75

# %%
# Device Type One-Hot Encoding
df_clean = pd.get_dummies(df_clean, columns=['device'], drop_first=True)
df_clean
# Out:
#   transaction_id user_id   amount location              time  is_fraud  hour  \
# 0          T1001    U001   850.00       LA  2024-05-10 12:34         0    12
# 3          T1004    U004  1299.50       SF  2024-06-13 03:45         1     3
# 4          T1005    U005   450.75       NY  2024-06-14 18:20         0    18
#
#    is_night  amount_zscore  device_OnePlus 9  device_iPhone 13
# 0         1      -0.039447             False             False
# 3         1       1.019140             False              True
# 4         1      -0.979693              True             False

# %%
# Build Feature Matrix (X) and Labels (y)
feature_cols = ['amount', 'hour', 'is_night', 'amount_zscore', 'mean', 'max']
X = df_grop[feature_cols].values
y = df_grop['is_fraud'].values

# %%
from scipy.spatial.distance import cdist

query = X[-1:]       # Last transaction
others = X[:-1]      # All previous
dists = cdist(query, others, metric='euclidean')
dists
# Out:
# array([[ 691.54795319, 1470.15600629]])
